# %%
cd /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/OISR/src
# Out:
# /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/OISR/src

# %%
# !python main.py --model EDSR --scale 1 --patch_size 48 --save OISR --data_train DIV2K --data_test DIV2K --n_feats 256 --dir_data ../../data --ext bin --gpu-id 0,1,2,3,4,5,6,7 --chop --epochs 800 --lr_decay 250 --n_GPUs 8 --loss 1*SL1 --lr 1e-4 --data_range 1-42/85-105
# Out:
# /home/purva/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# Loading ../../data/DIV2K/bin/train_bin_HR.pt...
# Loading ../../data/DIV2K/bin/train_bin_LR_X1.pt...
# Loading ../../data/DIV2K/bin/test_bin_HR.pt...
# Loading ../../data/DIV2K/bin/test_bin_LR_X1.pt...
# Making model...
#     Total params: 12.16M
# Preparing loss function:
# 1.000 * SL1
# [Epoch 1]	Learning rate: 1.00e-4
# [1600/15960]	[SL1: 9.3796]	29.3+0.1s
# [3200/15960]	[SL1: 8.4563]	29.0+0.0s
# [4800/15960]	[SL1: 8.1516]	29.2+0.0s
# [6400/15960]	[SL1: 7.9195]	29.5+0.0s
# [8000/15960]	[SL1: 7.7707]	29.6+0.0s
# [9600/15960]	[SL1: 7.6820]	29.6+0.0s
# [11200/15960]	[SL1: 7.6153]	29.7+0.0s
# [12800/15960]	[SL1: 7.5248]	29.9+0.0s
# [14400/15960]	[SL1: 7.4763]	29.7+0.0s
#
# Evaluation:
# ...

# %%
pwd
# Out:
# '/home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/OISR/src'

# %%
# !unzip /home/purva/Desktop/utk/data2.zip -d /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/
# Out:
# Archive:  /home/purva/Desktop/utk/data2.zip
#    creating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data2/
#    creating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data2/benchmark/
#    creating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data2/benchmark/B100/
#    creating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data2/benchmark/B100/HR/
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data2/benchmark/B100/HR/0000.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data2/benchmark/B100/HR/0001.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data2/benchmark/B100/HR/0002.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data2/benchmark/B100/HR/0003.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data2/benchmark/B100/HR/0004.png
# ...

# %%
cd /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/OISR/src
# Out:
# /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/OISR/src

# %%
# !cp /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/OISR/experiment/OISR/model/model_best.pt ./

# %%
# !python main.py --model EDSR --scale 1 --patch_size 48 --save OISR --data_train DIV2K --data_test B100 --n_feats 256 --dir_data ../../data2 --ext bin --gpu-id 0,1,2,3,4,5,6,7 --chop --epochs 100 --lr_decay 250 --n_GPUs 8 --loss 1*SL1 --lr 5e-5 --pre_train ./model_best.pt --data_range 1-52/85-105
# Out:
# /home/purva/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# Loading ../../data2/DIV2K/bin/train_bin_HR.pt...
# Loading ../../data2/DIV2K/bin/train_bin_LR_X1.pt...
# Loading ../../data2/benchmark/B100/bin/test_bin_HR.pt...
# Loading ../../data2/benchmark/B100/bin/test_bin_LR_X1.pt...
# Making model...
# Load the model from ./model_best.pt
#     Total params: 12.16M
# Preparing loss function:
# 1.000 * SL1
# [Epoch 1]	Learning rate: 5.00e-5
# [1600/15964]	[SL1: 5.0986]	29.4+0.1s
# [3200/15964]	[SL1: 5.0422]	29.1+0.0s
# [4800/15964]	[SL1: 5.0807]	29.4+0.0s
# [6400/15964]	[SL1: 5.0789]	29.7+0.0s
# [8000/15964]	[SL1: 5.0957]	29.9+0.0s
# [9600/15964]	[SL1: 5.0847]	30.0+0.0s
# [11200/15964]	[SL1: 5.0925]	29.8+0.0s
# [12800/15964]	[SL1: 5.1009]	30.0+0.0s
# ...

# %%
# !cp /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/OISR/experiment/OISR/model/model_best.pt ./

# %%
# !python main.py --model EDSR --scale 1 --patch_size 68 --save OISR --data_train DIV2K --data_test B100 --n_feats 256 --dir_data ../../data2 --ext bin --gpu-id 0,1,2,3,4,5,6,7 --chop --epochs 100 --lr_decay 250 --n_GPUs 8 --loss 1*SL1 --lr 1.5e-5 --pre_train ./model_best.pt --data_range 1-52/85-105
# Out:
# /home/purva/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# Loading ../../data2/DIV2K/bin/train_bin_HR.pt...
# Loading ../../data2/DIV2K/bin/train_bin_LR_X1.pt...
# Loading ../../data2/benchmark/B100/bin/test_bin_HR.pt...
# Loading ../../data2/benchmark/B100/bin/test_bin_LR_X1.pt...
# Making model...
# Load the model from ./model_best.pt
#     Total params: 12.16M
# Preparing loss function:
# 1.000 * SL1
# [Epoch 1]	Learning rate: 1.50e-5
# [1600/15964]	[SL1: 4.9577]	59.5+0.2s
# [3200/15964]	[SL1: 4.8862]	59.8+0.0s
# [4800/15964]	[SL1: 4.9053]	59.7+0.0s
# [6400/15964]	[SL1: 4.9116]	59.8+0.0s
# [8000/15964]	[SL1: 4.9330]	59.9+0.0s
# [9600/15964]	[SL1: 4.9183]	59.9+0.0s
# [11200/15964]	[SL1: 4.9118]	59.9+0.0s
# [12800/15964]	[SL1: 4.9211]	59.8+0.0s
# ...

# %%
# !unzip /home/purva/Desktop/utk/test_LR.zip -d /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data/benchmark/B100/
# Out:
# Archive:  /home/purva/Desktop/utk/test_LR.zip
#    creating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data/benchmark/B100/HR/
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data/benchmark/B100/HR/cam1_01.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data/benchmark/B100/HR/cam1_010.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data/benchmark/B100/HR/cam1_02.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data/benchmark/B100/HR/cam1_03.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data/benchmark/B100/HR/cam1_04.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data/benchmark/B100/HR/cam1_05.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data/benchmark/B100/HR/cam1_06.png
#   inflating: /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/data/benchmark/B100/HR/cam1_07.png
# ...

# %%
cd /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/OISR/src/
# Out:
# /home/purva/Desktop/utk/OISR-PyTorch-master/NTIRE2019/OISR/src

# %%
# !cp ../experiment/OISR/model/model_best.pt ./

# %%
# !python main.py --model EDSR --scale 1 --data_test B100 --n_feats 256 --dir_data ../../data --ext bin --gpu-id 0,1,2,3 --chop --n_GPUs 4 --pre_train ./model_best.pt --test_only --self_ensemble --save_results
# Out:
# /home/purva/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# Loading ../../data/benchmark/B100/bin/test_bin_HR.pt...
# Loading ../../data/benchmark/B100/bin/test_bin_LR_X1.pt...
# Making model...
# Load the model from ./model_best.pt
#     Total params: 12.16M
#
# Evaluation:
# 100%|██████████████████████████████████████████| 20/20 [48:13<00:00, 144.68s/it]
# [B100 x1]	PSNR: 32.235 (Best: 32.235 @epoch 1)
# Forward: 2893.87s
#
# Saving...
# Total: 2897.76s

# %%
# !python test_SRimages_rename.py

# %%
import torch
torch.__version__
# Out:
# '0.4.1.post2'

# %%
# !git clone https://github.com/fperazzi/proSR.git
# Out:
# Cloning into 'proSR'...
# remote: Enumerating objects: 1016, done.
# remote: Total 1016 (delta 0), reused 0 (delta 0), pack-reused 1016
# Receiving objects: 100% (1016/1016), 1.10 MiB | 708.00 KiB/s, done.
# Resolving deltas: 100% (608/608), done.
# Checking connectivity... done.
